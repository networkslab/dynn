# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
file_name = 'acc.csv'
df = pd.read_csv(file_name)
sns.set(font_scale=1)  # crazy big

# %%
plot_title = 'percent'
single = df.query("key == 'train/cheating_acc'")
sns.lineplot(data=df, x="step", y="value", hue="key")
plt.ylabel('early exit fraction')
plt.savefig(os.path.join('figures',plot_title+'.pdf'))

# %%
plt.close()
