# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = [[0.456, 15.03, 31.41],
[0.471, 15.79, 32.80],
[0.487, 16.75, 34.25],
[0.506, 18.00, 35.92],
[0.530, 19.37, 38.04],
[0.556, 21.03, 40.27],
[0.586, 23.10, 42.78],
[0.620, 25.11, 45.71],
[0.656, 27.67, 48.80],
[0.694, 30.60, 51.93],
[0.731, 33.50, 55.05],
[0.758, 36.26, 57.26],
[0.789, 39.48, 59.69],
[0.812, 42.09, 61.62],
[0.835, 45.09, 63.38],
[0.850, 47.59, 64.59],
[0.866, 50.21, 65.82],
[0.879, 52.88, 66.84],
[0.889, 54.89, 67.58],
[0.898, 56.82, 68.32],
[0.905, 58.89, 68.88],
[0.914, 60.64, 69.54],
[0.919, 62.18, 69.97],
[0.922, 63.37, 70.23],
[0.926, 64.79, 70.51],
[0.931, 66.19, 70.90],
[0.933, 67.29, 71.10],
[0.936, 68.50, 71.28],
[0.939, 69.46, 71.54],
[0.940, 70.43, 71.63],
[0.941, 71.09, 71.67],
[0.942, 71.87, 71.81],
[0.943, 72.52, 71.87],
[0.944, 73.07, 71.90],
[0.944, 73.60, 71.96],
[0.945, 74.31, 72.04],
[0.946, 74.83, 72.08],
[0.946, 75.31, 72.09]]

# %%
zdata = []
xdata = []
ydata = []
for three_dpoint in data:
    zdata.append(three_dpoint[0]*100.0)
    xdata.append(three_dpoint[1])
    ydata.append(three_dpoint[2])

# %%
fig = plt.figure()

ax = plt.axes(projection='3d')



ax.set_ylabel('calibration')
ax.set_zlabel('acc')
ax.set_xlabel('cost')
ax.scatter3D(xdata, ydata, zdata, c=zdata);
plt.tight_layout()
plt.show()

# %%
df_3d = pd.DataFrame()
df_3d['cost'] = xdata
df_3d['calibration error'] = ydata
df_3d['acc'] = zdata
sns.pairplot(df_3d)
plt.savefig('3d_pair.pdf')
