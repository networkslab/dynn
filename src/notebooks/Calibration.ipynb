# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
import matplotlib
import os

# %%
file_name = 'ece.csv'
df = pd.read_csv(file_name)
sns.set(font_scale=1)  # crazy big
print(df)
sns.lineplot(data=df, x="step", y="value", hue="key")
plt.xlabel('batch')
plt.ylabel('ECE')
plt.tight_layout()
plt.savefig('calibration_per_gate.pdf')
# Out:
#                                run_id         key     value   step  \
# 0    fd7e5d9709854592bd413ccb3999afe5  train/ece0  0.341611  35190
# 1    fd7e5d9709854592bd413ccb3999afe5  train/ece0  0.215593  35191
# 2    fd7e5d9709854592bd413ccb3999afe5  train/ece0  0.205236  35192
# 3    fd7e5d9709854592bd413ccb3999afe5  train/ece0  0.201442  35193
# 4    fd7e5d9709854592bd413ccb3999afe5  train/ece0  0.184018  35194
# ..                                ...         ...       ...    ...
# 295  fd7e5d9709854592bd413ccb3999afe5  train/ece4  0.083303  35235
# 296  fd7e5d9709854592bd413ccb3999afe5  train/ece4  0.082064  35236
# 297  fd7e5d9709854592bd413ccb3999afe5  train/ece4  0.080607  35237
# 298  fd7e5d9709854592bd413ccb3999afe5  train/ece4  0.079643  35238
# 299  fd7e5d9709854592bd413ccb3999afe5  train/ece4  0.078817  35239
#
#          timestamp
# 0    1689621164225
# 1    1689621165935
# 2    1689621166591
# 3    1689621166945
# 4    1689621167309
# ..             ...
# 295  1689621184493
# 296  1689621184847
# 297  1689621185224
# 298  1689621185578
# 299  1689621185939
#
# [300 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 for g in range(6):
# ----> 3     cor_g = list(df[df['key']=='test/hamming_cor'+str(g)]['value'])[-1]
#       4     inc_cor_g = list(df[df['key']=='test/hamming_corinc'+str(g)]['value'])[-1]
#       5     print(cor_g)
#
# IndexError: list index out of range
